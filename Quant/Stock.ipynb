# %%
from stocker import Stocker
import warnings
warnings.filterwarnings('ignore')

# %%
ms = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-27.

# %%
stock_history = ms.stock
stock_history.head()
# Out:
#         Date   Open   High   Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1986-03-13  25.50  29.25  25.5  28.00  3582600.0          0.0          1.0
# 1 1986-03-14  28.00  29.50  28.0  29.00  1070000.0          0.0          1.0
# 2 1986-03-17  29.00  29.75  29.0  29.50   462400.0          0.0          1.0
# 3 1986-03-18  29.50  29.75  28.5  28.75   235300.0          0.0          1.0
# 4 1986-03-19  28.75  29.00  28.0  28.25   166300.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close   Adj. Volume         ds  \
# 0   0.058941   0.067609  0.058941    0.064720  1.031789e+09 1986-03-13
# 1   0.064720   0.068187  0.064720    0.067031  3.081600e+08 1986-03-14
# 2   0.067031   0.068765  0.067031    0.068187  1.331712e+08 1986-03-17
# 3   0.068187   0.068765  0.065876    0.066454  6.776640e+07 1986-03-18
# 4   0.066454   0.067031  0.064720    0.065298  4.789440e+07 1986-03-19
#
#           y  Daily Change
# 0  0.064720      0.005779
# 1  0.067031      0.002311
# 2  0.068187      0.001156
# 3  0.066454     -0.001734
# 4  0.065298     -0.001156

# %%
ms.plot_stock()
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 89.47 on 2018-03-27.

# %%
ms.buy_and_hold(start_date='1986-03-13', end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
ms.buy_and_hold(start_date='1999-01-05', end_date='2002-01-03', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1999-01-05 to 2002-01-03 for 100 shares = $-56.92

# %%
model,model_data = ms.create_prophet_model()

# %%
model.plot_components(model_data)

# %%
model, future = ms.create_prophet_model(days=180)
# Out:
# Predicted Price on 2018-09-23 = $105.06

# %%
amazon = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 to 2018-03-27.

# %%
amazon.plot_stock()
amazon.plot_stock(stats=['Daily Change'])
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12.
# Minimum Adj. Close = 1.40 on 1997-05-22.
# Current Adj. Close = 1497.05 on 2018-03-27.
# Maximum Daily Change = 81.38 on 2018-02-06.
# Minimum Daily Change = -79.20 on 2018-02-08.
# Current Daily Change = -75.35 on 2018-03-27.

# %%
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# Predicted Price on 2018-06-25 = $1879.57

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $1054.94.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $16.86.
# Average Absolute Error on Testing  Data = $138.46.
#
# When the model predicted an increase, the price increased 56.41% of the time.
# When the model predicted a  decrease, the price decreased  40.22% of the time.
#
# The actual value was within the 80% confidence interval 60.24% of the time.

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.1, 0.2, 0.4, 0.6, 0.8])
# Out:
# Validation Range 2016-01-04 to 2017-01-03.
#
#    cps  train_err  train_range    test_err   test_range
# 0  0.1  10.688326    34.592836  149.458035   170.360549
# 1  0.2   9.816318    32.189975  125.815115   309.570277
# 2  0.4   8.658074    29.114956   81.492242   710.397266
# 3  0.6   8.223391    28.006092   70.083564  1029.825558
# 4  0.8   8.098925    27.621083   73.604174  1099.077058

# %%
amazon.changepoint_prior_scale = 0.6

# %%
amazon.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $967.61.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $10.68.
# Average Absolute Error on Testing  Data = $202.49.
#
# When the model predicted an increase, the price increased 60.96% of the time.
# When the model predicted a  decrease, the price decreased  47.06% of the time.
#
# The actual value was within the 80% confidence interval 81.53% of the time.

# %%
amazon.predict_future(days=10)
# Out:
# Predicted Increase:
#
#          Date     estimate     change        upper        lower
# 1  2018-03-28  1574.350100   2.107798  1596.395307  1552.270300
# 2  2018-03-29  1578.063044   3.712944  1601.377620  1558.547231
# 3  2018-03-30  1584.423177   6.360133  1606.246257  1563.953765
# 5  2018-04-01  1597.377361  12.954183  1617.876284  1575.690943
# 6  2018-04-02  1599.188631   1.811270  1620.148794  1577.180497
# 8  2018-04-04  1598.948476   0.357094  1620.441670  1576.922860
# 9  2018-04-05  1602.782931   3.834455  1625.196734  1580.898326
# 10 2018-04-06  1609.574777   6.791845  1630.784627  1586.431946
#
# Predicted Decrease:
#
#         Date     estimate    change        upper        lower
# 7 2018-04-03  1598.591381 -0.597249  1621.233886  1576.005488
